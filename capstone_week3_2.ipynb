# %%
import pandas as pd
import numpy as np

import geocoder as geocoder

#Read the datas from the wikipedia
df = pd.read_html('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M')[0]
df.columns = ['PostalCode', 'Borough', 'Neighborhood']

#drop the rows with Not assigned values in Borough ant the first column, because this contains column names
df = df[(df['Borough'] != 'Not assigned')].iloc[1:]

#Where Neighborhood is Not assigned then fill with Borough
df['Neighborhood'][df['Neighborhood']=='Not assigned'] = df['Borough'] 

#set column names
newpd = pd.DataFrame(columns = ['PostalCode', 'Borough', 'Neighborhood', 'Latitude', 'Longitude'])

gs = pd.read_csv("http://cocl.us/Geospatial_data")

#group datas by PostalCode
for index, row in df.iterrows():
   if newpd.loc[newpd['PostalCode'] == row['PostalCode']].empty:
      # initialize your variable to None
      select_indices = list(np.where(gs["Postal Code"] == row['PostalCode'])[0])
      
      latitude = gs.iloc[select_indices[0]]['Latitude']
      longitude = gs.iloc[select_indices[0]]['Longitude']
      newpd.loc[len(newpd)] = [row['PostalCode'], row['Borough'], row['Neighborhood'], latitude, longitude]
   else :
      select_indices = list(np.where(newpd["PostalCode"] == row['PostalCode'])[0])
      newpd.loc[select_indices, 'Neighborhood'] = newpd.loc[select_indices, 'Neighborhood'] + ',' + row['Neighborhood']

print(newpd)
# Out:
#     PostalCode           Borough  \
# 0          M3A        North York
# 1          M4A        North York
# 2          M5A  Downtown Toronto
# 3          M6A        North York
# 4          M7A      Queen's Park
# 5          M9A         Etobicoke
# 6          M1B       Scarborough
# 7          M3B        North York
# 8          M4B         East York
# 9          M5B  Downtown Toronto
# 10         M6B        North York
# 11         M9B         Etobicoke
# 12         M1C       Scarborough
# 13         M3C        North York
# 14         M4C         East York
# 15         M5C  Downtown Toronto
# 16         M6C              York
# 17         M9C         Etobicoke
# 18         M1E       Scarborough
# 19         M4E      East Toronto
# 20         M5E  Downtown Toronto
# 21         M6E              York
# 22         M1G       Scarborough
# 23         M4G         East York
# 24         M5G  Downtown Toronto
# 25         M6G  Downtown Toronto
# 26         M1H       Scarborough
# ...
